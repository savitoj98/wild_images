# %%
import numpy as np
import cv2 as cv
# import video
import sys
if __name__ == '__main__':
#      try:
#          video_src = sys.argv[1]
#      except:
#          video_src = 0
    cam = cv.VideoCapture(0)
#      cam = video.create_capture(video_src)
    mser = cv.MSER_create()
    while True:
        ret, img = cam.read()
        if ret == 0:
            break
        gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
        vis = img.copy()
        regions, _ = mser.detectRegions(gray)
        hulls = [cv.convexHull(p.reshape(-1, 1, 2)) for p in regions]
        cv.polylines(vis, hulls, 1, (0, 255, 0))
 
        cv.imshow('img', vis)
        if cv.waitKey(5) == 27:
            break
    cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv
# import video
import sys

if __name__ == '__main__':
    mser = cv.MSER_create()
#     img = cv.imread("images/hindi.jpg")
#     img = cv.imread("images/final.jpg")
    img = cv.imread("python-swt/final3.jpg")
    vis = img.copy()
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    regions, bboxes = mser.detectRegions(gray)
    hulls = [cv.convexHull(p.reshape(-1, 1, 2)) for p in regions]
    cv.polylines(vis, hulls, 1, (0, 255, 0))
    print("vis : ", type(vis))
    cv.imshow('img', vis)
    cv.imwrite("mser11.jpg", vis)
    i=0
    name = str(i)
    for p in regions:
        vis = img.copy()
        hull = cv.convexHull(p.reshape(-1, 1, 2))
        cv.polylines(vis, hull, 1, (0, 255, 0))
#         print(hull)
#         print(type(hull))
#         print(type(p))
        print(p)
        cv.imwrite("regions" + str(i)+".jpg", vis)
        i+=1
        print(i)

#     for p in bboxes:
#         vis = img.copy()
#         print(p)
#         print("next")
#         cv.rectangle(vis, (p[0], p[1]), (p[2], p[3]), (0, 255, 0))
#         cv.imwrite(str(i)+".jpg", vis)
#         i+=1
#         print(i)

#     print(img[0:100][0:100])
#     for p in bboxes:
#         print(p)
#         a = p[0]
#         b = p[0]+p[2]
#         c = p[1]
#         d = p[1]+p[3]
#         print(a, " ", b, " ", c, " ", d)
# #         cv.imwrite(str[i]+".jpg", img[p[0]:p[0]+p[2]] [p[1]:p[1]+p[3]])
# #         cv.imwrite(str[i]+".jpg", img[a:b][c:d])
#         cv.imwrite(str(i)+"final.jpg", img[a:c][b:d])
#         cv.waitKey(0)
#         i+=1
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# vis :  <class 'numpy.ndarray'>
# [[215 229]
#  [217 229]
#  [216 228]
#  ...
#  [228 236]
#  [229 214]
#  [217 207]]
# 1
# [[471 292]
#  [472 291]
#  [473 290]
#  ...
#  [483 299]
#  [473 276]
#  [493 315]]
# 2
# [[554 278]
#  [554 277]
#  [553 277]
#  [554 279]
#  [554 280]
#  [553 280]
#  [553 281]
#  [553 282]
#  [553 283]
#  [553 284]
#  [553 285]
#  [553 286]
#  [553 287]
#  [553 288]
#  [553 289]
#  [553 290]
#  [553 291]
#  [553 292]
#  [553 293]
#  [553 294]
#  [553 295]
#  [553 296]
#  [553 297]
#  [553 298]
#  [553 299]
#  [553 300]
#  [553 301]
#  [553 302]
#  [553 303]
#  [553 304]
#  [553 305]
#  [553 306]
#  [553 307]
#  [553 308]
#  [553 309]
#  [553 310]
#  [553 311]
#  [554 311]
#  [555 311]
#  [555 310]
#  [555 309]
#  [555 308]
#  [555 307]
#  [555 306]
#  [555 305]
#  [555 304]
#  [555 303]
#  [555 302]
#  [555 301]
#  [555 300]
#  [555 299]
#  [555 298]
#  [555 297]
#  [555 296]
#  [555 295]
#  [555 294]
#  [555 293]
#  [555 292]
#  [555 291]
#  [555 290]
# ...

# %%
import cv2

img = cv2.imread("images/hindi.jpg")

sift = cv2.xfeatures2d.SIFT_create()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-b8aec714c752> in <module>()
#       3 img = cv2.imread("images/hindi.jpg")
#       4
# ----> 5 sift = cv2.xfeatures2d.SIFT_create()
#
# AttributeError: module 'cv2.cv2' has no attribute 'xfeatures2d'

# %%
# import pillowfight
from PIL import Image
from PIL import swt
import cv2
import numpy

input_image = Image.open("test.jpg")
output_img = swt(input_image)
im = numpy.asarray(output_img)
cv2.imwrite('ouut.jpg', im)
print(output_img)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-d0be610768c0> in <module>()
#       1 # import pillowfight
#       2 from PIL import Image
# ----> 3 from PIL import swt
#       4 import cv2
#       5 import numpy
#
# ImportError: cannot import name 'swt'
